# %%
from mypysort import bubble_sort
from mypysort import quick_sort
import numpy as np

a = np.array([3, 1, 4, 1, 5, 9, 2, 6])

b = bubble_sort.sort(a)
c = quick_sort.sort(a)

print(b)
print(c)
# Out:
# [1 1 2 3 4 5 6 9]
# [1 1 2 3 4 5 6 9]

# %%
# 1から10000までの乱数を5000桁生成

a = np.random.randint(1, 10000, 5000)

# バブルソートの時間計測
import time
start = time.time()
bubble_sort.sort(a)
end = time.time()

print("bubble_sort: ", end - start)

# クイックソートの時間計測
start = time.time()
quick_sort.sort(a)
end = time.time()

print("quick_sort: ", end - start)
# Out:
# bubble_sort:  0.07103824615478516
# quick_sort:  0.0017178058624267578

# %%
x = [100, 500, 1000, 5000, 10000, 15000, 20000, 25000, 30000, 35000]

bubble_time = []
quick_time = []

for i in x:
    a = np.random.randint(1, 10000, i)
    start = time.time()
    bubble_sort.sort(a)
    end = time.time()
    bubble_time.append(end - start)

    start = time.time()
    quick_sort.sort(a)
    end = time.time()
    quick_time.append(end - start)

import matplotlib.pyplot as plt

plt.plot(x, bubble_time, label="bubble_sort")
plt.plot(x, quick_time, label="quick_sort")
plt.legend()
plt.show()
